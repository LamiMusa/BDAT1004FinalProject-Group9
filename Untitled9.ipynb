# %%
# !pip install opendatasets

import opendatasets as od
od.download("https://www.kaggle.com/datasets/gregorut/videogamesales")
# Out:
# ...
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: lamimusa
# Your Kaggle Key: ········
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 381k/381k [00:04<00:00, 81.7kB/s]

# %%
import pandas

# %%
da = pd.read_csv('vgsales.csv')
for index, row in da.iterrows():
    data3 = row.to_dict()
    print(data3)
# Out:
# {'Rank': 1, 'Name': 'Wii Sports', 'Platform': 'Wii', 'Year': 2006.0, 'Genre': 'Sports', 'Publisher': 'Nintendo', 'NA_Sales': 41.49, 'EU_Sales': 29.02, 'JP_Sales': 3.77, 'Other_Sales': 8.46, 'Global_Sales': 82.74}
# {'Rank': 2, 'Name': 'Super Mario Bros.', 'Platform': 'NES', 'Year': 1985.0, 'Genre': 'Platform', 'Publisher': 'Nintendo', 'NA_Sales': 29.08, 'EU_Sales': 3.58, 'JP_Sales': 6.81, 'Other_Sales': 0.77, 'Global_Sales': 40.24}
# {'Rank': 3, 'Name': 'Mario Kart Wii', 'Platform': 'Wii', 'Year': 2008.0, 'Genre': 'Racing', 'Publisher': 'Nintendo', 'NA_Sales': 15.85, 'EU_Sales': 12.88, 'JP_Sales': 3.79, 'Other_Sales': 3.31, 'Global_Sales': 35.82}
# {'Rank': 4, 'Name': 'Wii Sports Resort', 'Platform': 'Wii', 'Year': 2009.0, 'Genre': 'Sports', 'Publisher': 'Nintendo', 'NA_Sales': 15.75, 'EU_Sales': 11.01, 'JP_Sales': 3.28, 'Other_Sales': 2.96, 'Global_Sales': 33.0}
# ...

# %%
type(data3)
# Out:
# dict

# %%
# !pip install pymongo[srv]

from pymongo import MongoClient
import time

# %%
client = MongoClient("mongodb+srv://lami:lamimusa@projectcluster.mll2uph.mongodb.net/?retryWrites=true&w=majority")
db = client["sample_sales"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['ac-bhlqw0y-shard-00-02.mll2uph.mongodb.net:27017', 'ac-bhlqw0y-shard-00-01.mll2uph.mongodb.net:27017', 'ac-bhlqw0y-shard-00-00.mll2uph.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-eteiiq-shard-0', tls=True), 'sample_sales')

# %%
while True:
    db.vid_sales.insert_one(data3)
    time.sleep(86400)
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# Input In [54], in <cell line: 2>()
#       1 while True:
# ----> 2     db.vid_sales.insert_one(data3)
#       3     time.sleep(86400)
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:628, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     624     document["_id"] = ObjectId()  # type: ignore[index]
#     626 write_concern = self._write_concern_for(session)
#     627 return InsertOneResult(
# --> 628     self._insert_one(
#     629         document,
#     630         ordered=True,
#     631         write_concern=write_concern,
#     632         op_id=None,
#     633         bypass_doc_val=bypass_document_validation,
#     634         session=session,
#     635         comment=comment,
#     636     ),
#     637     write_concern.acknowledged,
#     638 )
#
# ...
